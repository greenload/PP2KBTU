# %% [markdown]
# Lab work 1

# %% [markdown]
# Syntax

# %%
print("Hello World")
# Out:
# Hello World

# %%
if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# Comment

# %%
#This is a comment

# %%
"""
This is a comment
written in 
more than just one line
"""

# %% [raw]
# Variables

# %% [markdown]
# Data types

# %% [markdown]
# Numbers

# %% [markdown]
# Strings
